# %% [markdown]
#  # Assignment 3
#  ### [정보]
#  #### 1) Due Date: 2018년 10월 29일 (월), 23시 59분
#  #### 2) 제출방법: jupyter notebook으로 작성된 내용을 github 또는 dropbox와 같은 클라우드에 올려 해당 URL을 다시 http://nbviewer.jupyter.org 에 넣어서 산출된 URL을 EL사이트에 제출함.
#  #### 3) 내용: 반드시 python code와 수행 결과를 jupyter notebook 내에 작성하여 넣고 이에 대한 설명등을 해당 코드 아래에 markdown cell에 넣어 기입하시오.
#  #### 4) 숙제이후 소감: 문제를 모두 푼 이후에 현재까지 강의를 들은 이후의 소감, 숙제를 한 이후의 소감, 또는 전하고자 하는 말 등을 짧막하게라도 좋으니 마지막에 함께 작성하여 제출하시오.
#  #### 5) 문제 (ACM-ICPC 1문제 포함하여 총 9개)

# %% [markdown]
#  ### L=[1, 2, 3, 4, 5]일 때 다음 각 문장을 수행한 후의 결과를 보고 납득할 만한 이유를 설명하시오.
#    - 1)<pre>L[1:3] = [100]
#     print(L)</pre>

# %%
L=[1,2,3,4,5]
L[1:3] = [100]
print (L)
print(L[1:3])
# Out:
# [1, 100, 4, 5]
# [100, 4]

# %% [markdown]
# - L[1:3] 슬라이싱 연산으로 L[1]~L[2]까지 영역 즉, [2,3]을 [100] 으로 치환한다.

# %% [markdown]
#  - 2)<pre>L[1:3] = [(100)]
#     print(L)</pre>

# %%
L=[1,2,3,4,5]
L[1:3] = [(100)]
print (L)
# Out:
# [1, 100, 4, 5]

# %% [markdown]
# - [(100)] 리스트의 원소가 100이 아닌 (100)이지만 여기서 ()는 튜플을 나타내는 괄호가 아닌 표현식에서 우선순위로 묶어주는 의미의 ()이다. 따라서 L[1:3] = [2,3]이 [100]으로 치환된다.

# %% [markdown]
#    - 3)<pre>L[1:3] = 100
#     print(L)</pre>

# %%
L=[1,2,3,4,5]
L[1:3] = 100
print(L)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-de14f99aa378> in <module>()
#       1 L=[1,2,3,4,5]
# ----> 2 L[1:3] = 100
#       3 print(L)
#
# TypeError: can only assign an iterable

# %% [markdown]
# - 위의 L[1:3] 슬라이싱 연산을 통해서 잘라낸 값은 [2,3] 으로 원소가 2개인 리스트이다. 따라서 정수값인 100으로 치환할 경우 에러가 발생한다. 튜플, 사전처럼 원소를 집합적으로 표현한 반복가능한 객체는 치환이 가능하다.

# %% [markdown]
# - 4)<pre>L[1:3] = (100)
#     print(L)</pre>

# %%
L=[1,2,3,4,5]
L[1:3] = 100
print(L)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-de14f99aa378> in <module>()
#       1 L=[1,2,3,4,5]
# ----> 2 L[1:3] = 100
#       3 print(L)
#
# TypeError: can only assign an iterable

# %% [markdown]
# - 위의 L[1:3] 슬라이싱 연산을 통해서 지정한 영역은 [2,3] 으로 리스트이다. (100)은 튜플이 아닌 정수값 100이다. 따라서 정수값인 100으로 치환할 경우 에러가 발생한다.

# %% [markdown]
#    - 5)<pre>L[1:3] = (100, 101, 102)
#     print(L)</pre>

# %%
L=[1,2,3,4,5]
L[1:3] = (100,101,102)
print(L)
# Out:
# [1, 100, 101, 102, 4, 5]

# %% [markdown]
# - L[1:3] 슬라이싱 연산을 통해 지정한 영역 [2,3]을 (100,101,102)로 치환한다. 따라서 2,3 자리에 100,101,102로 치환되고 4,5는 뒤로 밀려난다. 여기서 ()는 원소의 집합적인 표현으로 반복가능한 객체를 의미한다.

# %% [markdown]
# - 6)<pre>L[1:3] = [100, 101, 102]
#     print(L)</pre>

# %%
L=[1,2,3,4,5]
L[1:3] = [100,101,102]
print(L)
# Out:
# [1, 100, 101, 102, 4, 5]

# %% [markdown]
# - L[1:3] 슬라이싱 연산을 통해 지정한 영역 [2,3]을 [100,101,102]로 치환한다. 따라서 2,3 자리에 100,101,102로 치환되고 4,5는 뒤로 밀려난다.

# %% [markdown]
#
#    - 7)<pre>L[1:3] = [(100, 101, 102)]
#     print(L)</pre>

# %%
L=[1,2,3,4,5]
L[1:3] = [(100,101,102)]
print(L)
# Out:
# [1, (100, 101, 102), 4, 5]

# %% [markdown]
# - [(100,101,102)] 는 튜플을 하나의 원소로 가지는 리스트를 의미한다. 따라서 (100,101,102)가 하나의 원소이므로 L[1:3] = [2,3]이 (100,101,102)로 치환된다.

# %% [markdown]
# - 8)<pre>L[1:3] = [[100, 101, 102]]
#     print(L)</pre>

# %%
L=[1,2,3,4,5]
L[1:3] = [[(100,101,102)]]
print(L)
# Out:
# [1, [(100, 101, 102)], 4, 5]

# %% [markdown]
# - [[100,101,102]] 는 리스트를 하나의 원소로 가지는 리스트를 의미한다. 따라서 [100,101,102]가 하나의 원소이므로 L[1:3] = [2,3]이 [100,101,102]로 치환된다.

# %% [markdown]
# ### 문자열 S = 'Hello World and Python'에 대해 다음 요구사항에 대한 Python 코드를 제시하시오.
#    #### 1) 단어의 순서가 역순으로 되어진 문자열 ('Python and World Hello')을 만들고
#    #### 2) 1)의 결과 문자열에 대해 메소드 split과 join을 이용하여 공백을 모두 없엔 문자열 'PythonandWorldHello'을 만드시오.

# %%
#1번 문제
s = 'Hello World and Python' 
s = s[::-1]      #문자열 뒤집고
s = s.split()    #공백단위분리
l = [w[::-1] for w in s] #뒤집어진 각각의 단어를 뒤집은 리스트 반환
s = ' '.join(l) #공백문자로 연결한 문자열
print(s)

#2번 문제
s = s.split(" ") #공백단위로 자르고
s = "".join(s) #''문자 단위로 연결
print(s)
# Out:
# Python and World Hello
# PythonandWorldHello

# %% [markdown]
#  ### 다음 코드를 보고 물음에 답하시오.
#    <pre>a = [1, 2, 3]
#    b = a &#42; 3
#    c = [a] &#42; 3
#    print(b)
#    print(c)</pre>

# %% [markdown]
# #### 1) 위 코드를 수행한 이후 다음 코드를 수행한 후 b와 c의 내용을 확인하시오.
#      <pre>a[0]=0</pre>

# %%
a = [1,2,3]
b = a * 3
c = [a] * 3
print(b)
print(c)

a[0] = 0
print(b)
print(c)
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
# [[1, 2, 3], [1, 2, 3], [1, 2, 3]]
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
# [[0, 2, 3], [0, 2, 3], [0, 2, 3]]

# %% [markdown]
# #### 2) b와 c 객체의 차이는 무엇인가?

# %% [markdown]
# - b객체는 a 리스트가 3개 연결된 새로운 리스트의 레퍼런스를 가리키는 객체이다. c객체는 a 리스트를 하나의 원소로 갖는 리스트를 3개 연결한 새로운 리스트를 가리키는 객체이다. c 리스트의 전체 틀은 새로운 리스트이지만 c의 원소는 각각 a 리스트를 가리키는 레퍼런스이다. 즉, c의 각각의 원소와 a는 동일한 리스트를 가리키는 레퍼런스다. 따라서 a[0]의 값을 변경하면 c의 각각 원소의 리스트의 값도 변경된다.

# %% [markdown]
#  ### 다음 문자열을 ':'을 기준으로 분리하여 리스트로 만들고 각 문자열의 좌우 공백을 제거하시오 (즉, 문자열 S에서 l을 만들어라)
#  <pre>
#  s = '  first star   :   second star   :    third star  '
#  l = ['first star', 'second star', 'third star']
#  </pre>
#    #### 1) for ~ in 문을 이용한 코드를 작성하시오.

# %%
s = '  first star   :   second star   :    third star  '.split(":") # ':' 문자 단위 분리 리스트
l = []
for w in s:        # 리스트 각 단어를
    l.append(w.strip()) #좌우 공백을 제거한 새로운 리스트에 저장
print(l)
# Out:
# ['first star', 'second star', 'third star']

# %% [markdown]
# #### 2) 리스트 내포(list comprehension)를 이용한 코드를 작성하시오.

# %%
s = '  first star   :   second star   :    third star  '.split(":") # ':' 문자 단위 분리 리스트
s = [w.strip() for w in s]  # s의 각 원소의 좌우 공백이 제거된 문자가 원소로 된 리스트
print(s)
# Out:
# ['first star', 'second star', 'third star']

# %% [markdown]
#  ###  다음과 같이 0보다 큰 정수 리스트 변수 list를 인자로 받는 함수 addall(list)와 addallodd(list)를 for ~ in 리터널과 리스트 내포 방식으로 각각 제시하시오.
#
#     - [참고 1]: 리스트 내포 방식으로 addall() 및 addallodd()함수를 만들 때엔 리스트 내포에 의해 생성된 리스트 결과에 대해 내장 함수를 사용하는 방식을 고려해보시오 (주의: 리스트 내포 방식의 addall() 및 addallodd() 함수의 몸체는 단 1줄로 작성되어야 한다.)
#    - [참고 2]: sum() 등의 내장함수 사용 가능함
#
#
#    #### 1) addall(list) 함수 (리스트 내의 모든 정수를 더하는 함수로서 해답으로는 for ~ in 리터럴과 리스트 내포 방식으로 각각 제시하시오.)
#      - <pre>>>> addall([1])
#      1</pre>
#      - <pre>>>> addall([1, 2, 3, 4, 5, 6, 7, 8, 9])
#      45</pre>

# %%
def addall(l):
    sum = 0
    for n in l : sum += n
    return sum
print(addall([1]))
print(addall([1,2,3,4,5,6,7,8,9]))
# Out:
# 1
# 45

# %%
def addall(l):
    return sum([n for n in l])  ## l의 각 원소가 그대로 원소로 구성된 리스트의 합을 반환
print(addall([1])) 
print(addall([1,2,3,4,5,6,7,8,9]))
# Out:
# 1
# 45

# %% [markdown]
# #### 2) addallodd(list) 함수 (리스트내의 모든 홀수를 더하는 함수로서 해답으로는 for ~ in 리터럴과 리스트 내포 방식으로 각각 제시하시오.)
#      - <pre>>>> addallodd([1])
#      1</pre>
#      - <pre>>>> addallodd([1, 2, 3, 4, 5, 6, 7, 8, 9])
#      25</pre>

# %%
def addallodd(l):
    sum = 0
    for n in l :
        if n % 2 == 1 :sum += n #홀수만 더한다.
    return sum

print(addallodd([1])) 
print(addallodd([1,2,3,4,5,6,7,8,9]))
# Out:
# 1
# 25

# %%
def addalladd(l):
    return sum([n for n in l if n % 2 == 1]) #ㅣ의 원소중 홀수만 원소로가지는 새로운 리스트의 합을 반환

print(addallodd([1])) 
print(addallodd([1,2,3,4,5,6,7,8,9]))
# Out:
# 1
# 25

# %% [markdown]
# ### 다음 코드를 보고 물음에 답하시오.
#    <pre>L1 = [1, 2, 3]
#  L2 = [4, 5, 6]
#  d = {'low':L1, 'high':L2}
#  e = d
#  f = d.copy()
#  print(d)
#  print(e)
#  print(f)
#  print()
#  d['low'] = [10, 20, 30]
#  d['high'][1] = 500
#  print(d)
#  print(e)
#  print(f)</pre>
#
#  ####  1) 위 코드의 수행 결과 d와 e는 항상 같은 결과를 출력한다. 그 이유는 무엇인가?

# %% [markdown]
# - d객체는 사전의 레퍼런스를 가리키고 e객체는 d의 레퍼런스를 가리킨다. 즉 d,e는 같은 레퍼런스를 가리키기 때문에 d와 e는 같은 사전을 공유한다. 때문에 d가 수정되면 e도 수정된다.

# %% [markdown]
#    ####  2) 위 코드의 수행 결과 마지막 f의 내용은 다음과 같다. 이 때 'high' 키의 값 내용 중 500이 출력된 이유와 'low' 키의 값 내용 중 [1, 2, 3]이 출력된 이유를 설명하시오 ([hint]: shallow copy 관점에서 설명하시오.)
#    <pre>{'high': [4, 500, 6], 'low': [1, 2, 3]}</pre>

# %% [markdown]
# - f는 d와 동일한 키와 값을 가진 {'low':L1, 'high':L2}과 같은 새로운 객체로 생성된다. 그러나 여기서 L1, L2는 각각 리스트의 레퍼런스로 d와 같은 리스트의 레퍼런스를 가리킨다. 따라서 d['low'] = [10, 20, 30]에서 d['low']가 새로운 리스트의 레퍼런스를 가리키기 때문에 f는 변하지 않지만 d['high'][1] = 500은 리스트인 L2의 원소를 변경하기 때문에 같은 리스트를 가리키는 f['high']도 동일한 값이 출력된다.

# %% [markdown]
#  ### 사전 d = {'one':1, 'two':2, 'three':3, 'four':4, 'five':5}가 주어졌을 때 다음 요구사항에 맞는 코드를 제시하시오
#    - [참고]: d.keys(), d.values()를 통해 리스트를 얻어낸 후 리스트가 지니고 있는 sort(cmp=None, key=None, reverse=False)함수를 활용하시오.
#
# #### 1) 키의 알파벳 오름차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.

# %%
d = {'one':1, 'two':2, 'three':3, 'four':4, 'five':5}
items = list(d.items())
items.sort()
print (items)
# Out:
# [('five', 5), ('four', 4), ('one', 1), ('three', 3), ('two', 2)]

# %% [markdown]
#    #### 2) 키의 알파벳 내림차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.

# %%
items = list(d.items())
items.sort(reverse=True)
print (items)
# Out:
# [('two', 2), ('three', 3), ('one', 1), ('four', 4), ('five', 5)]

# %% [markdown]
# #### 3) 값의 오름차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.

# %%
def cmp_by_each_element(a):
    return a[1]

items = list(d.items())
items.sort(key=cmp_by_each_element)
print (items)
# Out:
# [('one', 1), ('two', 2), ('three', 3), ('four', 4), ('five', 5)]

# %% [markdown]
# ####  4) 값의 내림차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.

# %%
def cmp_by_each_element(a):
    return a[1]

items = list(d.items())
items.sort(key=cmp_by_each_element,reverse=True)
print (items)
# Out:
# [('five', 5), ('four', 4), ('three', 3), ('two', 2), ('one', 1)]

# %% [markdown]
# ### [ACM-ICPC 문제 1673번]
# ####  치킨 쿠폰
#    - 문제 : 강민이는 치킨 한 마리를 주문할 수 있는 치킨 쿠폰을 n장 가지고 있다. 이 치킨집에서는 치킨을 한 마리 주문할 때마다 도장을 하나씩 찍어 주는데, 도장을 k개 모으면 치킨 쿠폰 한 장으로 교환할 수 있다. 강민이가 지금 갖고 있는 치킨 쿠폰으로 치킨을 최대 몇 마리나 먹을 수 있는지 구하여라. 단, 치킨을 주문하기 위해서는 반드시 치킨 쿠폰을 갖고 있어야 한다.
#    - 입력 : 여러 줄에 걸쳐서 자연수 n과 k가 주어진다.
#    - 출력 : 각 입력마다 한 줄에 정답을 출력한다.
#    - 제한 : 1 < k ≤ n ≤ 1,000,000,000

# %%
import sys
for line in sys.stdin: #테스트 케이스를 한줄 씩 읽어온다.
    coupon, k = map(int,line.split())  #치킨쿠폰, 쿠폰교환도장개수 k를 공백단위로 분리해 각각 정수값으로 저장한다
    order = stamp = coupon   #쿠폰 수 만큼 치킨 주문. 주문 수 만큼 도장을 받음
    
    while(stamp >= k):  #갖고있는 도장 수가 k보다 많으면 반복해서 치킨 추가주문 계산
        order += int(stamp / k) # 도장 수를 k로 나눈만큼 추가 주문
        stamp = int(stamp / k) + int(stamp % k) #추가 주문한 만큼 받은 도장 수 + 추가 주문하고 남은 도장 수
    print (order)

# %% [markdown]
# ![이미지](https://github.com/woooooojin/ScriptProgrammingAssignment3/blob/master/1673.PNG?raw=true)

# %% [markdown]
#  - 이미지URL : https://github.com/woooooojin/ScriptProgrammingAssignment3/blob/master/1673.PNG?raw=true

# %% [markdown]
#  ### [Incremental Project] 이전 Assignment 2의 마지막 문제는 웹 URL로 지정된 웹페이지를 문자열로 가져와 모든 HTML 태그를 제외한 순수 텍스트를 얻어내고 그 안에 존재하는 단어를 추출하고 단어들의 총 개수를 출력하는 프로그램을 작성하는 것이었다. 이번에는 그 마지막 숙제를 그대로 확장하여 웹 URL로 지정된 웹페이지 내 순수 텍스트 안에 존재하는 각 단어들에 대해 다음 요구사항 대로 출력하는 프로그램을 작성하시오.
#    - 요구사항 1. CSS와 Javascript 내용도 모두 제거하시오 (이전 숙제에서 이미 제외하였다면 본 요구사항 무시)
#      - 즉, 아래와 같은 코드는 <style\> 및 <script\>태그 뿐만 아니라 그 안의 내용 전체를 모두 제거
#        ```
#       <style>
#       h1 {
#          color: blue;
#        }
#        </style>
#      ```
#
#          ```
#        <script>
#        int a = 10;
#        ...
#        </script>
#      ```
#    - 요구사항 2. 순수 텍스트 안에 존재하는 단어들에 대해 string 모듈을 활용하여 모든 punctuation (구두문자)를 완벽히 제거하시오.
#      - 예: ['world!', ':', '+hello+', '~python$$$', '=', 'world'] ---> ['world', 'hello', 'python', 'world']
#      - 모든 punctuation을 확인하는 방법은 아래와 같다.
#      <pre>
#      import string
#      print(string.punctuation)
#      </pre>
#    - 요구사항 3. 만약 punctuation (구두문자)를 제거한 이후 공백으로 판명되는 단어들은 해당 단어 리스트에서 제거하시오.
#      - 예: ['컴퓨터공학부!', '---?', '%지향~', '...'] ---> ['컴퓨터공학부', '', '지향', ''] ---> ['컴퓨터공학부', '지향']
#   <br/><br/>
#    - 요구사항 3. 각 단어들의 출현빈도를 사전형태로 저장하여 출력하시오.
#      - 예: ['world', 'hello', 'python', 'world', '컴퓨터공학부', '지향'] ---> {'world': 2, 'hello': 1, 'python': 1, '컴퓨터공학부': 1, '지향': 1}
#   <br/><br/>
#    - 요구사항 4. 다음 5개의 사이트에 대한 단어 출현빈도 결과를 출력하시오.
#      - http://cse.koreatech.ac.kr
#      - https://www.koreatech.ac.kr
#      - http://www.naver.com
#      - http://www.daum.net
#      - http://www.nytimes.com

# %%
def extractText(source): #HTML태그를 제외하고 순수 텍스트만 추출하는 함수
    text = "" #순수 텍스트 식별자
    while(1) :      
        source = source[source.find('<'):] #'<'를 찾는다
        if (source.find("<!--") == 0) : 
                source = source[source.find("-->")+3:] #주석 내용 건너뜀 
        elif (source.find("<script") == 0) :        
                source = source[source.find("</script>")+9:]  #자바스크립트 내용 건너뜀   
        elif (source.find("<style") == 0) :
                source = source[source.find("</style>")+9:] #스타일 내용 건너뜀
        else :       
            source = source[source.find('>')+1:] #'>'를 찾는다
            for ch in source :    #'>' 이후부터 한글자씩 가져온다
                if ch == '<' : break    # 다시 '<' 문자 등장하면 종료
                elif ch == '\t' or ch == '\n' : continue    #탭,개행 문자는 순수 텍스트에 포함x
                else : text += ch   #순수 텍스트 추가     
            if text.endswith(" ") == False : text += " " #공백으로 분리하기 위해 순수 텍스트 추출 후 뒤에 공백문자 추가
        if(source.find('<') == -1):break #'<' 문자가 더 이상 없는 경우 무한루프종료 
    return text

# %%
import string

def replaceAll(text, dic):  ##문자열을 사전에 맵핑된 문자로 대체로 하는 함수
    for i,j in dic.items():
        text = text.replace(i,j,text.count(i)) #문자열에 사전에 키와 같은 문자가 존재하면 키에 맵핑된 value값으로 대체한다.
    return text   

def stripSpecialChar(text): ##특수문자 제거 함수
    keys = [ch for ch in string.punctuation] #구두문자를 key리스트로 만듬
    keys.append("★") #구두문자 이외의 특수문자를 key리스트에 추가
    keys.append("☆")
    keys.append("※")
    keys.append("nbsp")#html문자
    keys.append("lt")
    keys.append("amp")
    keys.append("quot")
    keys.append("middot")
    keys.append("uarr")
    keys.append("rarr")
    keys.append("darr")
    keys.append("harr")
    
    values = ['' for _ in keys]  #key리스트의 원소 수 만큼 ''문자를 원소를 갖는 value리스트를 만듬
    replaceDic = dict(zip(keys,values)) #key리스트 key로 value리스트를 value값으로 하는 사전 만듬

    return replaceAll(text,replaceDic) #추출한 순수 텍스트에서 사전에 맵핑된 제거할 문자들을 모두 제거

# %%
def wordOfFreq(l): #단어의 빈도수를 사전으로 반환하는 함수
    word = []   
    for w in l: #리스트의 각 원소들이
        if (w in word) == False : word.append(w) #word리스트에 포함된 단어가 아니면 단어를 리스트에 추가 (단어중복제거)          
    freg = [l.count(w) for w in l] #리스트에서 단어의 출현 빈도수를 리스트로 만듬
    
    return dict(zip(word,freg)) #단어와 단어의 빈도수로 맵핑된 사전 반환

# %%
import requests

req = requests.get('http://cse.koreatech.ac.kr')
source = req.text

# %%
text =  extractText(source)  #순수 텍스트 추출
text = stripSpecialChar(text) #특수문자 제거
l = text.split()            #공백단위분리
print(wordOfFreq(l)) #출현한 단어의 빈도수
# Out:
# {'컴퓨터공학부': 7, 'Schoolfun': 1, 'Study': 1, 'and': 3, 'Fun': 1, '로그인': 4, '아이디': 4, '비밀번호': 1, '유지': 1, '브라우저를': 4, '닫더라도': 2, '로그인이': 1, '계속': 1, '유지될': 1, '수': 1, '있습니다': 1, '기능을': 2, '사용할': 1, '경우': 4, '다음': 2, '접속부터는': 1, '로그인할': 1, '필요가': 1, '없습니다': 1, '단': 1, '게임방': 1, '학교': 1, '등': 1, '공공장소에서': 1, '이용': 1, '시': 1, '개인정보가': 1, '유출될': 1, '있으니': 1, '꼭': 1, '로그아웃을': 1, '해주세요': 1, '회원가입': 2, 'IDPW': 1, '찾기': 1, 'IT': 1, '교육의': 1, '글로벌': 1, '메카': 1, '한국기술교육대학교': 1, 'Close': 5, '소개': 2, '구성원소개': 3, '학사안내': 2, '입학': 7, '학부': 7, '대학원': 1, '학부광장': 1, '자료실': 1, '공학교육인증': 1, '학부서비스': 1, 'Registration': 1, 'School': 2, 'of': 1, 'Computer': 2, 'Science': 2, 'Engineering': 1, '융합소프트웨어': 1, '인력양성사업': 1, 'CK': 7, 'Creative': 1, 'KoreaI': 2, '교육역량강화사업': 1, '온라인': 1, '컨텐츠': 3, 'Online': 1, 'Contents': 5, 'for': 3, 'Education': 3, 'Capability': 1, 'Empowerment': 1, '홈페이지에': 1, '오신': 3, '것을': 4, '환영합니다': 2, '수준의': 1, 'IT전문인력': 1, '양성': 2, 'IT융합분야에': 1, '대한': 1, '국제적인': 1, '경쟁력': 5, '고취': 2, '바로가기': 
# ...

# %%
req = requests.get('https://www.koreatech.ac.kr')
source = req.text

# %%
text =  extractText(source)  #순수 텍스트 추출
text = stripSpecialChar(text) #특수문자 제거
l = text.split()            #공백단위분리
print(wordOfFreq(l)) #출현한 단어의 빈도수
# Out:
# {'한국기술교육대학교': 3, '홈페이지': 3, '주요메뉴': 1, '바로가기': 3, '본문': 1, '하단메뉴': 3, '현재': 1, '스크립트가': 3, '꺼져': 1, '있는': 1, '상태입니다': 1, '스크립트를': 1, '사용하지': 1, '않으시면': 1, '이용에': 1, '불편사항이': 1, '있습니다': 3, '스크립트': 1, '사용을': 1, '권장합니다': 1, 'KOREATECH': 1, '탑': 1, '유틸메뉴': 1, '오류신고': 17, 'HOME': 3, 'LOGIN': 2, 'WEBMAIL': 2, 'SITEMAP': 3, 'ENGLISH': 1, 'CHINESE': 1, '통합검색': 2, '입력폼': 2, 'facebook': 1, 'daum': 2, 'naver': 2, 'youtube': 1, '대학소개': 1, '대한민국': 2, '기술리더': 2, '세계를': 2, '품다': 2, 'KOREATECH소개': 4, '총장실': 4, '대학현황': 4, 'VISION2020': 1, 'KOREATECH20년': 1, '대학조직': 17, '국제교류': 1, '코리아텍발전기금': 1, 'KOREATECH부패방지': 2, '입학안내': 2, '학생이': 2, '행복한': 2, '대학': 2, '학생중심': 2, '교육중심': 2, '대학원': 2, '대학대학원': 2, '기업이': 6, '신뢰하는': 6, '1위': 6, '일학습병행대학': 2, '대학생활': 1, '대한민국의': 8, '미래를': 17, '선도하는': 1, '행복대학': 2, '학사안내': 8, '해외연수': 4, '장학제도': 6, '캠퍼스생활': 6, '병사안내': 6, '커뮤니티': 1, '도전': 1, '열정': 8, '창의': 17, '재학생': 2, '만족도': 3, '취업률': 8, '공지사항': 8, '참여게시판': 4, '자료실': 3, '휴먼아카데미명사특강': 4, '취업역량강화동영상': 4, '교수·학습역량강화특강': 4, 
# ...

# %%
req = requests.get('http://www.naver.com')
source = req.text

# %%
text =  extractText(source)  #순수 텍스트 추출
text = stripSpecialChar(text) #특수문자 제거
l = text.split()            #공백단위분리
print(wordOfFreq(l)) #출현한 단어의 빈도수
# Out:
# {'NAVER': 3, '뉴스스탠드': 2, '바로가기': 6, '주제별캐스트': 1, '타임스퀘어': 6, '쇼핑캐스트': 2, '로그인': 6, '네이버': 2, '네이버를': 6, '시작페이지로': 4, '쥬니어네이버': 6, '해피빈': 9, '검색': 1, '통합검색': 1, '블로그': 1, '카페': 1, '카페명': 2, '카페글': 1, '지식iN': 2, '뉴스': 2, '사이트': 1, '카테고리': 1, '영화': 1, '웹문서': 5, '사전': 2, '백과사전': 1, '영어사전': 2, '영영사전': 4, '국어사전': 1, '일본어사전': 2, '한자사전': 1, '용어사전': 1, '책': 1, '음악': 1, '전문자료': 1, '쇼핑': 1, '지역': 1, '동영상': 2, '이미지': 2, '내PC': 1, '자동차': 2, '게임': 2, '건강': 1, '인물': 1, '긍정부정검색': 1, '자동완성': 4, '펼치기': 2, '한글': 6, '입력기': 2, '생각한대로': 1, '검색해': 1, '보세요': 17, 'Beta': 5, 'txt': 2, '시간대와': 1, '관심사에': 1, '맞춘': 1, '컨텍스트': 1, '도움말': 2, '보기': 1, 'ON': 4, '선택됨': 4, 'OFF': 1, '동일한': 2, '시간대연령남녀별': 1, '사용자': 3, '그룹의': 17, '맞춰': 6, '자동완성을': 21, '제공합니다': 1, '자세히': 1, 'ONOFF설정은': 1, '해당': 3, '기기브라우저에': 17, '저장됩니다': 1, '레이어': 1, '닫기': 1, '신고': 1, '검색어저장': 2, '켜기': 1, '끄기': 1, '기능을': 1, '다시': 4, '켤': 2, '때는': 1, '을': 1, '클릭하세요': 1, '현재': 1, '사용하고': 2, '계십니다': 3, '기능이': 17, '활성화되었습니다': 1, '꺼져': 3, '있습니다': 6, '최근검색어': 4
# ...

# %%
req = requests.get('http://www.daum.net')
source = req.text

# %%
text =  extractText(source)  #순수 텍스트 추출
text = stripSpecialChar(text) #특수문자 제거
l = text.split()            #공백단위분리
print(wordOfFreq(l)) #출현한 단어의 빈도수
# Out:
# {'Daum': 1, '주요': 2, '서비스': 5, '바로가기': 11, '오늘의': 6, '정보': 8, '미디어': 11, '실시간': 3, '이슈': 11, '멀티미디어': 4, '블로그': 4, '유익한': 11, '쇼핑': 2, '포토영상': 11, '웹': 5, '접근성': 8, '안내': 11, '자동실행': 2, '광고': 8, '설정': 11, '검색': 3, '통합': 11, '한글입력기': 6, '인기': 1, '검색어': 11, '서울': 1, '지하철역': 1, '라돈': 1, '아이유': 1, '슬럼프': 1, '먼시': 1, '홈런': 8, '전참시': 2, '위너': 8, '억만장자': 1, '총자산': 8, '더': 1, '서울어워즈': 3, '롤드컵': 1, '4강': 1, '이준기': 1, '최민수': 1, '지리산': 1, '첫눈': 2, '다뉴브': 1, '강': 1, '금화': 1, '이전': 1, 'gt다음': 1, '다음을': 1, '시작페이지로': 1, '카페': 1, '메일': 1, '뉴스': 1, '지도': 1, '증권': 1, '카카오TV': 1, '웹툰': 1, '브런치': 1, '사전': 1, '게임': 7, '별플레이': 1, '같이가치': 1, '주요서비스': 1, '더보기': 2, '⋁': 5, '전체': 3, '커뮤니케이션': 2, '티스토리': 5, '아지트': 2, '카카오스토리': 1, '스포츠': 3, '연예': 3, '아고라': 3, '쇼핑생활': 5, '쇼핑하우': 3, '항공권': 1, '신규업데이트': 3, '금융': 1, '부동산': 3, '자동차': 1, '미즈넷': 2, '문화엔터': 1, '영화': 5, '나눔펀딩': 5, '스토리펀딩': 1, '사전지식': 2, '어학사전': 3, '번역': 5, '단어장': 2, '백과사전': 3, '팁': 1, '배틀그라운드': 2, '검은사막': 3, '길찾기': 5, '로드뷰': 4, '버스정보': 2, '지하철노선도': 1, '
# ...

# %% [markdown]
# ### [소감]
#
#  - 이번 과제를 수행하면서 파이썬이 제공하는 모듈, 함수가 잘되어있어서 코딩하기가 편하다고 생각했던 것을 다시 한번 생각해보게 되었습니다. 제공하는 모듈이나 함수등이 많다보니 그 기능이나 함수를 다시 기억하고 찾아보고 하는데 시간이 많이 들었던것 같습니다. 파이썬 문법에 대해서 다시한번 확실히 기억하고 파이썬언어로 코딩연습을 좀 더 해야겠다는 생각이 들었습니다. 파이썬이 아닌 다른 언어의 스타일로 문제를 해결하려고 하다보니 무언가 코드가 더 간결해질 수 있음을 느끼면서도 그 방법을 다시 찾아내느라 시간이 좀 더 걸린것 같습니다. 특히 백준 문제를 풀때 런타임에러가 상당히 많이 나는데 입력조건 대해서 파이썬 스타일로 하는데 아직 익숙하지 않은 것 같습니다.
